# %% [markdown]
# <a href="https://colab.research.google.com/github/RC0ndado/CIAACD/blob/main/DBAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/gdrive")
# !pwd
# Out:
# Mounted at /content/gdrive
# /content

# %%
#put your own path in google drive
# %cd "/content/gdrive/MyDrive/Equipo8/ConnectBD"
# !ls
# Out:
# /content/gdrive/MyDrive/Equipo8/ConnectBD
# 'Copia de Untitled0.ipynb'   kaggle   kaggle_j.json   kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
#Libraries
from google.colab import files
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# !chmod 600 kaggle.json

# %%
import shutil
shutil.copy('/content/gdrive/MyDrive/Equipo8/ConnectBD/content/kaggle.json', '/root/.kaggle/kaggle.json')
# Out:
# '/root/.kaggle/kaggle.json'

# %%
import kaggle

kaggle.api.authenticate()

# %%
# !kaggle datasets list
# Out:
# ref                                                                   title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/countries-of-the-world-2023                          Global Country Information Dataset 2023             23KB  2023-07-08 20:37:33          11284        450  1.0
# nelgiriyewithana/global-youtube-statistics-2023                       Global YouTube Statistics 2023                      60KB  2023-07-28 15:36:38           3395        133  1.0
# joebeachcapital/global-earth-temperatures                             Global Earth Temperatures                           33KB  2023-08-09 06:21:51            718         29  1.0
# joebeachcapital/top-500-hollywood-movies-of-all-time                  Top 500 Hollywood Movies of All Time                33KB  2023-08-03 01:08:52            755         27  1.0
# arnavsmayan/netflix-userbase-dataset                                  Netflix Userbase Dataset                            25KB  2023-07-04 07:38:41          12502        222  1.0
# joebeachcapital/fast-food                                             Fast Food Nutrition                                 20KB  2023-08-09 01:35:51            749         32  1.0
# anshtanwar/global-data-on-sustainable-energy                          Global Data on Sustainable Energy (2000-2020)      175KB  2023-08-07 11:58:00           2613         42  1.0
# juhibhojani/house-price                                               House Price                                          7MB  2023-08-02 16:51:21           1561         54  0.9411765
# alphiree/cardiovascular-diseases-risk-prediction-dataset              Cardiovascular Diseases Risk Prediction Dataset      5MB  2023-07-03 12:12:19           9118        302  1.0
# joebeachcapital/marvel-movies                                         Marvel Superhero Movies                              2KB  2023-08-02 23:31:11            450         25  1.0
# sivapriyagarladinne/telangana-post-monsoon-ground-water-quality-data  Water Quality Data [Telangana Groundwater]          79KB  2023-07-28 17:25:06            623         28  1.0
# lasaljaywardena/age-dataset-2023                                      The Age Dataset 2023 - Global and General Purpose   39MB  2023-08-04 11:56:01            767         33  1.0
# joebeachcapital/top-2000-companies-globally                           Top 2000 Companies Globally                         38KB  2023-07-31 01:06:07            658         31  1.0
# joebeachcapital/gpa-and-iq                                            GPA & IQ                                            795B  2023-08-09 05:05:39            458         28  1.0
# georgeggcoco/closeness-of-music-genres                                Spotify's top 3000 music genres - Network           17MB  2023-08-04 13:27:45            342         25  1.0
# joebeachcapital/life-expectancy                                       Life Expectancy                                    149KB  2023-08-09 02:21:33            374         23  1.0
# abhijitdahatonde/zomato-restaurants-dataset                           Zomato Restaurants Dataset                         181KB  2023-07-20 13:11:17           1390         44  1.0
# ibrahimonmars/imdb-reviews-on-barbie                                  IMDB Reviews on Barbie                               5MB  2023-08-04 04:47:14            442         39  1.0

# %%
# Download kaggle data of houses
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# Downloading house-prices-advanced-regression-techniques.zip to /content/gdrive/MyDrive/Equipo8/ConnectBD
#   0% 0.00/199k [00:00<?, ?B/s]
# 100% 199k/199k [00:00<00:00, 17.4MB/s]

# %%
# !unzip house-prices-advanced-regression-techniques.zip
# Out:
# Archive:  house-prices-advanced-regression-techniques.zip
#   inflating: data_description.txt
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
#Load datasets

df = pd.read_csv("/content/gdrive/MyDrive/Equipo8/ConnectBD/content/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#Obtain datatypes
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.shape
# Out:
# (1460, 81)

# %%
import pandas as pd
import json

# Load CSV into a DataFrame
df = pd.read_csv("/content/gdrive/MyDrive/Equipo8/ConnectBD/content/train.csv")

# Analyze the columns of the DataFrame
data_analysis = {}
for column in df.columns:
    data_type = df[column].dtype
    if data_type in ["int64", "float64"]:
        classification = "numeric"
    else:
        classification = "categorical"

    # Convert numpy types to native Python types for JSON serialization
    example_value = df[column].iloc[0]
    if isinstance(example_value, (np.int64, np.float64, np.int32)):
        example_value = int(example_value)

    data_analysis[column] = {
        "data_type": str(data_type),
        "unique_values": int(df[column].nunique()),
        "missing_values": int(df[column].isnull().sum()),
        "example_value": example_value,
        "classification": classification
    }

# Convert analysis to JSON format
data_analysis_json = json.dumps(data_analysis, indent=4)

# Display column names
print("Column Names:")
print(df.columns.tolist())

# Provide a data example for each column in JSON format
data_example = df.iloc[0].astype(str).to_dict()  # Convert all values to string for JSON serialization
data_example_json = json.dumps(data_example, indent=4)

print("\nData Example in JSON Format:")
print(data_example_json)
# Out:
# Column Names:
# ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']
#
# Data Example in JSON Format:
# {
#     "Id": "1",
#     "MSSubClass": "60",
#     "MSZoning": "RL",
#     "LotFrontage": "65.0",
#     "LotArea": "8450",
#     "Street": "Pave",
#     "Alley": "nan",
#     "LotShape": "Reg",
#     "LandContour": "Lvl",
#     "Utilities": "AllPub",
#     "LotConfig": "Inside",
#     "LandSlope": "Gtl",
#     "Neighborhood": "CollgCr",
#     "Condition1": "Norm",
#     "Condition2": "Norm",
#     "BldgType": "1Fam",
#     "HouseStyle": "2Story",
#     "OverallQual": "7",
#     "OverallCond": "5",
#     "YearBuilt": "2003",
#     "YearRemodAdd": "2003",
#     "RoofStyle": "Gable",
#     "RoofMatl": "CompShg",
#     "Exterior1st": "VinylSd",
#     "Exterior2nd": "VinylSd",
#     "MasVnrType": "BrkFace",
#     "MasVnrArea": "196.0",
#     "ExterQual": "Gd",
#     "ExterCond": "TA",
#     "Foundation": "PConc",
#     "BsmtQual": "Gd",
#     "BsmtCond": "TA",
#     "BsmtExposure": "No",
#     "BsmtFinType1": "GLQ",
#     "BsmtFinSF1": "706",
#     "BsmtFinType2": "Unf",
#     "BsmtFinSF2": "0",
#     "BsmtUnfSF": "150",
#     "TotalBsmtSF": "856",
#     "Heating": "GasA",
#     "HeatingQC": "Ex",
#     "CentralAir": "Y",
#     "Electrical": "SBrkr",
#     "1stFlrSF": "856",
#     "2ndFlrSF": "854",
#     "LowQualFinSF": "0",
#     "GrLivArea": "1710",
#     "BsmtFullBath": "1",
#     "BsmtHalfBath": "0",
#     "FullBath": "2",
#     "HalfBath": "1",
#     "BedroomAbvGr": "3",
#     "KitchenAbvGr": "1",
#     "KitchenQual": "Gd",
#     "TotRmsAbvGrd": "8",
#     "Functional": "Typ",
#     "Fireplaces": "0",
#     "FireplaceQu": "nan",
#     "GarageType": "Attchd",
#     "GarageYrBlt": "2003.0",
#     "GarageFinish": "RFn",
#     "GarageCars": "2",
#     "GarageArea": "548",
#     "GarageQual": "TA",
#     "GarageCond": "TA",
#     "PavedDrive": "Y",
#     "WoodDeckSF": "0",
#     "OpenPorchSF": "61",
#     "EnclosedPorch": "0",
#     "3SsnPorch": "0",
#     "ScreenPorch": "0",
#     "PoolArea": "0",
#     "PoolQC": "nan",
#     "Fence": "nan",
#     "MiscFeature": "nan",
#     "MiscVal": "0",
#     "MoSold": "2",
#     "YrSold": "2008",
#     "SaleType": "WD",
#     "SaleCondition": "Normal",
#     "SalePrice": "208500"
# }

# %%
import numpy as np

# Analyze the columns of the DataFrame
data_analysis = {}
for column in df.columns:
    data_type = df[column].dtype
    if data_type in ["int64", "float64"]:
        classification = "numeric"
    else:
        classification = "categorical"

    # Convert numpy types to native Python types
    example_value = df[column].iloc[0]
    if isinstance(example_value, (np.int64, np.float64, np.int32)):
        example_value = int(example_value)

    data_analysis[column] = {
        "data_type": str(data_type),
        "unique_values": int(df[column].nunique()),
        "missing_values": int(df[column].isnull().sum()),
        "example_value": example_value,
        "classification": classification
    }

# Provide a data example for each column
data_example = df.iloc[0].astype(str).to_dict()

# Create a dictionary with the analysis and data example
analysis_dict = {
    "data_analysis": data_analysis,
    "data_example": data_example
}

analysis_dict
# Out:
# {'data_analysis': {'Id': {'data_type': 'int64',
#    'unique_values': 1460,
#    'missing_values': 0,
#    'example_value': 1,
#    'classification': 'numeric'},
#   'MSSubClass': {'data_type': 'int64',
#    'unique_values': 15,
#    'missing_values': 0,
#    'example_value': 60,
#    'classification': 'numeric'},
#   'MSZoning': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': 'RL',
#    'classification': 'categorical'},
#   'LotFrontage': {'data_type': 'float64',
#    'unique_values': 110,
#    'missing_values': 259,
#    'example_value': 65,
#    'classification': 'numeric'},
#   'LotArea': {'data_type': 'int64',
#    'unique_values': 1073,
#    'missing_values': 0,
#    'example_value': 8450,
#    'classification': 'numeric'},
#   'Street': {'data_type': 'object',
#    'unique_values': 2,
#    'missing_values': 0,
#    'example_value': 'Pave',
#    'classification': 'categorical'},
#   'Alley': {'data_type': 'object',
#    'unique_values': 2,
#    'missing_values': 1369,
#    'example_value': nan,
#    'classification': 'categorical'},
#   'LotShape': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 'Reg',
#    'classification': 'categorical'},
#   'LandContour': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 'Lvl',
#    'classification': 'categorical'},
#   'Utilities': {'data_type': 'object',
#    'unique_values': 2,
#    'missing_values': 0,
#    'example_value': 'AllPub',
#    'classification': 'categorical'},
#   'LotConfig': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': 'Inside',
#    'classification': 'categorical'},
#   'LandSlope': {'data_type': 'object',
#    'unique_values': 3,
#    'missing_values': 0,
#    'example_value': 'Gtl',
#    'classification': 'categorical'},
#   'Neighborhood': {'data_type': 'object',
#    'unique_values': 25,
#    'missing_values': 0,
#    'example_value': 'CollgCr',
#    'classification': 'categorical'},
#   'Condition1': {'data_type': 'object',
#    'unique_values': 9,
#    'missing_values': 0,
#    'example_value': 'Norm',
#    'classification': 'categorical'},
#   'Condition2': {'data_type': 'object',
#    'unique_values': 8,
#    'missing_values': 0,
#    'example_value': 'Norm',
#    'classification': 'categorical'},
#   'BldgType': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': '1Fam',
#    'classification': 'categorical'},
#   'HouseStyle': {'data_type': 'object',
#    'unique_values': 8,
#    'missing_values': 0,
#    'example_value': '2Story',
#    'classification': 'categorical'},
#   'OverallQual': {'data_type': 'int64',
#    'unique_values': 10,
#    'missing_values': 0,
#    'example_value': 7,
#    'classification': 'numeric'},
#   'OverallCond': {'data_type': 'int64',
#    'unique_values': 9,
#    'missing_values': 0,
#    'example_value': 5,
#    'classification': 'numeric'},
#   'YearBuilt': {'data_type': 'int64',
#    'unique_values': 112,
#    'missing_values': 0,
#    'example_value': 2003,
#    'classification': 'numeric'},
#   'YearRemodAdd': {'data_type': 'int64',
#    'unique_values': 61,
#    'missing_values': 0,
#    'example_value': 2003,
#    'classification': 'numeric'},
#   'RoofStyle': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 0,
#    'example_value': 'Gable',
#    'classification': 'categorical'},
#   'RoofMatl': {'data_type': 'object',
#    'unique_values': 8,
#    'missing_values': 0,
#    'example_value': 'CompShg',
#    'classification': 'categorical'},
#   'Exterior1st': {'data_type': 'object',
#    'unique_values': 15,
#    'missing_values': 0,
#    'example_value': 'VinylSd',
#    'classification': 'categorical'},
#   'Exterior2nd': {'data_type': 'object',
#    'unique_values': 16,
#    'missing_values': 0,
#    'example_value': 'VinylSd',
#    'classification': 'categorical'},
#   'MasVnrType': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 8,
#    'example_value': 'BrkFace',
#    'classification': 'categorical'},
#   'MasVnrArea': {'data_type': 'float64',
#    'unique_values': 327,
#    'missing_values': 8,
#    'example_value': 196,
#    'classification': 'numeric'},
#   'ExterQual': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 'Gd',
#    'classification': 'categorical'},
#   'ExterCond': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': 'TA',
#    'classification': 'categorical'},
#   'Foundation': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 0,
#    'example_value': 'PConc',
#    'classification': 'categorical'},
#   'BsmtQual': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 37,
#    'example_value': 'Gd',
#    'classification': 'categorical'},
#   'BsmtCond': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 37,
#    'example_value': 'TA',
#    'classification': 'categorical'},
#   'BsmtExposure': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 38,
#    'example_value': 'No',
#    'classification': 'categorical'},
#   'BsmtFinType1': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 37,
#    'example_value': 'GLQ',
#    'classification': 'categorical'},
#   'BsmtFinSF1': {'data_type': 'int64',
#    'unique_values': 637,
#    'missing_values': 0,
#    'example_value': 706,
#    'classification': 'numeric'},
#   'BsmtFinType2': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 38,
#    'example_value': 'Unf',
#    'classification': 'categorical'},
#   'BsmtFinSF2': {'data_type': 'int64',
#    'unique_values': 144,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'BsmtUnfSF': {'data_type': 'int64',
#    'unique_values': 780,
#    'missing_values': 0,
#    'example_value': 150,
#    'classification': 'numeric'},
#   'TotalBsmtSF': {'data_type': 'int64',
#    'unique_values': 721,
#    'missing_values': 0,
#    'example_value': 856,
#    'classification': 'numeric'},
#   'Heating': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 0,
#    'example_value': 'GasA',
#    'classification': 'categorical'},
#   'HeatingQC': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': 'Ex',
#    'classification': 'categorical'},
#   'CentralAir': {'data_type': 'object',
#    'unique_values': 2,
#    'missing_values': 0,
#    'example_value': 'Y',
#    'classification': 'categorical'},
#   'Electrical': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 1,
#    'example_value': 'SBrkr',
#    'classification': 'categorical'},
#   '1stFlrSF': {'data_type': 'int64',
#    'unique_values': 753,
#    'missing_values': 0,
#    'example_value': 856,
#    'classification': 'numeric'},
#   '2ndFlrSF': {'data_type': 'int64',
#    'unique_values': 417,
#    'missing_values': 0,
#    'example_value': 854,
#    'classification': 'numeric'},
#   'LowQualFinSF': {'data_type': 'int64',
#    'unique_values': 24,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'GrLivArea': {'data_type': 'int64',
#    'unique_values': 861,
#    'missing_values': 0,
#    'example_value': 1710,
#    'classification': 'numeric'},
#   'BsmtFullBath': {'data_type': 'int64',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 1,
#    'classification': 'numeric'},
#   'BsmtHalfBath': {'data_type': 'int64',
#    'unique_values': 3,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'FullBath': {'data_type': 'int64',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 2,
#    'classification': 'numeric'},
#   'HalfBath': {'data_type': 'int64',
#    'unique_values': 3,
#    'missing_values': 0,
#    'example_value': 1,
#    'classification': 'numeric'},
#   'BedroomAbvGr': {'data_type': 'int64',
#    'unique_values': 8,
#    'missing_values': 0,
#    'example_value': 3,
#    'classification': 'numeric'},
#   'KitchenAbvGr': {'data_type': 'int64',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 1,
#    'classification': 'numeric'},
#   'KitchenQual': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 'Gd',
#    'classification': 'categorical'},
#   'TotRmsAbvGrd': {'data_type': 'int64',
#    'unique_values': 12,
#    'missing_values': 0,
#    'example_value': 8,
#    'classification': 'numeric'},
#   'Functional': {'data_type': 'object',
#    'unique_values': 7,
#    'missing_values': 0,
#    'example_value': 'Typ',
#    'classification': 'categorical'},
#   'Fireplaces': {'data_type': 'int64',
#    'unique_values': 4,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'FireplaceQu': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 690,
#    'example_value': nan,
#    'classification': 'categorical'},
#   'GarageType': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 81,
#    'example_value': 'Attchd',
#    'classification': 'categorical'},
#   'GarageYrBlt': {'data_type': 'float64',
#    'unique_values': 97,
#    'missing_values': 81,
#    'example_value': 2003,
#    'classification': 'numeric'},
#   'GarageFinish': {'data_type': 'object',
#    'unique_values': 3,
#    'missing_values': 81,
#    'example_value': 'RFn',
#    'classification': 'categorical'},
#   'GarageCars': {'data_type': 'int64',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': 2,
#    'classification': 'numeric'},
#   'GarageArea': {'data_type': 'int64',
#    'unique_values': 441,
#    'missing_values': 0,
#    'example_value': 548,
#    'classification': 'numeric'},
#   'GarageQual': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 81,
#    'example_value': 'TA',
#    'classification': 'categorical'},
#   'GarageCond': {'data_type': 'object',
#    'unique_values': 5,
#    'missing_values': 81,
#    'example_value': 'TA',
#    'classification': 'categorical'},
#   'PavedDrive': {'data_type': 'object',
#    'unique_values': 3,
#    'missing_values': 0,
#    'example_value': 'Y',
#    'classification': 'categorical'},
#   'WoodDeckSF': {'data_type': 'int64',
#    'unique_values': 274,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'OpenPorchSF': {'data_type': 'int64',
#    'unique_values': 202,
#    'missing_values': 0,
#    'example_value': 61,
#    'classification': 'numeric'},
#   'EnclosedPorch': {'data_type': 'int64',
#    'unique_values': 120,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   '3SsnPorch': {'data_type': 'int64',
#    'unique_values': 20,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'ScreenPorch': {'data_type': 'int64',
#    'unique_values': 76,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'PoolArea': {'data_type': 'int64',
#    'unique_values': 8,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'PoolQC': {'data_type': 'object',
#    'unique_values': 3,
#    'missing_values': 1453,
#    'example_value': nan,
#    'classification': 'categorical'},
#   'Fence': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 1179,
#    'example_value': nan,
#    'classification': 'categorical'},
#   'MiscFeature': {'data_type': 'object',
#    'unique_values': 4,
#    'missing_values': 1406,
#    'example_value': nan,
#    'classification': 'categorical'},
#   'MiscVal': {'data_type': 'int64',
#    'unique_values': 21,
#    'missing_values': 0,
#    'example_value': 0,
#    'classification': 'numeric'},
#   'MoSold': {'data_type': 'int64',
#    'unique_values': 12,
#    'missing_values': 0,
#    'example_value': 2,
#    'classification': 'numeric'},
#   'YrSold': {'data_type': 'int64',
#    'unique_values': 5,
#    'missing_values': 0,
#    'example_value': 2008,
#    'classification': 'numeric'},
#   'SaleType': {'data_type': 'object',
#    'unique_values': 9,
#    'missing_values': 0,
#    'example_value': 'WD',
#    'classification': 'categorical'},
#   'SaleCondition': {'data_type': 'object',
#    'unique_values': 6,
#    'missing_values': 0,
#    'example_value': 'Normal',
#    'classification': 'categorical'},
#   'SalePrice': {'data_type': 'int64',
#    'unique_values': 663,
#    'missing_values': 0,
#    'example_value': 208500,
#    'classification': 'numeric'}},
#  'data_example': {'Id': '1',
#   'MSSubClass': '60',
#   'MSZoning': 'RL',
#   'LotFrontage': '65.0',
#   'LotArea': '8450',
#   'Street': 'Pave',
#   'Alley': 'nan',
#   'LotShape': 'Reg',
#   'LandContour': 'Lvl',
#   'Utilities': 'AllPub',
#   'LotConfig': 'Inside',
#   'LandSlope': 'Gtl',
#   'Neighborhood': 'CollgCr',
#   'Condition1': 'Norm',
#   'Condition2': 'Norm',
#   'BldgType': '1Fam',
#   'HouseStyle': '2Story',
#   'OverallQual': '7',
#   'OverallCond': '5',
#   'YearBuilt': '2003',
#   'YearRemodAdd': '2003',
#   'RoofStyle': 'Gable',
#   'RoofMatl': 'CompShg',
#   'Exterior1st': 'VinylSd',
#   'Exterior2nd': 'VinylSd',
#   'MasVnrType': 'BrkFace',
#   'MasVnrArea': '196.0',
#   'ExterQual': 'Gd',
#   'ExterCond': 'TA',
#   'Foundation': 'PConc',
#   'BsmtQual': 'Gd',
#   'BsmtCond': 'TA',
#   'BsmtExposure': 'No',
#   'BsmtFinType1': 'GLQ',
#   'BsmtFinSF1': '706',
#   'BsmtFinType2': 'Unf',
#   'BsmtFinSF2': '0',
#   'BsmtUnfSF': '150',
#   'TotalBsmtSF': '856',
#   'Heating': 'GasA',
#   'HeatingQC': 'Ex',
#   'CentralAir': 'Y',
#   'Electrical': 'SBrkr',
#   '1stFlrSF': '856',
#   '2ndFlrSF': '854',
#   'LowQualFinSF': '0',
#   'GrLivArea': '1710',
#   'BsmtFullBath': '1',
#   'BsmtHalfBath': '0',
#   'FullBath': '2',
#   'HalfBath': '1',
#   'BedroomAbvGr': '3',
#   'KitchenAbvGr': '1',
#   'KitchenQual': 'Gd',
#   'TotRmsAbvGrd': '8',
#   'Functional': 'Typ',
#   'Fireplaces': '0',
#   'FireplaceQu': 'nan',
#   'GarageType': 'Attchd',
#   'GarageYrBlt': '2003.0',
#   'GarageFinish': 'RFn',
#   'GarageCars': '2',
#   'GarageArea': '548',
#   'GarageQual': 'TA',
#   'GarageCond': 'TA',
#   'PavedDrive': 'Y',
#   'WoodDeckSF': '0',
#   'OpenPorchSF': '61',
#   'EnclosedPorch': '0',
#   '3SsnPorch': '0',
#   'ScreenPorch': '0',
#   'PoolArea': '0',
#   'PoolQC': 'nan',
#   'Fence': 'nan',
#   'MiscFeature': 'nan',
#   'MiscVal': '0',
#   'MoSold': '2',
#   'YrSold': '2008',
#   'SaleType': 'WD',
#   'SaleCondition': 'Normal',
#   'SalePrice': '208500'}}

# %% [markdown]
# This heatmap of the correlations between the variables of the DataFrame. The lighter shades represent strong positive correlations, while the darker shades represent strong negative correlations. Areas in neutral tones (around the central color) indicate a weak or non-existent correlation between the variables.
#
# It is especially useful to observe how the other variables correlate with SalePrice (the last row/column) to determine which features have a more significant impact on the price.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = df.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(15, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title("Correlation Heatmap")
plt.show()
